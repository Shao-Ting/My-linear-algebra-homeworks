# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# %% [markdown]
# 定義 t 的範圍

# %%
t = np.linspace(-10, 10, 100)

# %% [markdown]
# 設計函數圖形

# %%
x = t**2
y = np.sin(t)

# %% [markdown]
# 畫出圖形

# %%
plt.plot(x, y)

# %% [markdown]
# 用可愛的方式再畫一次圖形

# %%
plt.xkcd()
plt.plot(x, y)
